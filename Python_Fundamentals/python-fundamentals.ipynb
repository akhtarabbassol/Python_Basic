# %% [markdown]
# Convert Celsius to Fahrenheit

# %%
C = float(input("Enter the Celcious nvalue: "))
F = (C*9/5)+32
print("Temperature in Foreinheight: ",F)
# Out:
# Temperature in Foreinheight:  41.0

# %% [markdown]
# Check whether a number is positive, negative, or zero.

# %%
def check_number(num):
    if num > 0:
        print(num, "is a Positive number")
    elif num < 0:
        print(num, "Is a Negative number")
    elif num == 0:
        print(num, "is a zero")
    else:
        print("Enter the correct Number")
num = float(input("Enter the Number: "))
check_number(num)
# Out:
# 5.0 is a Positive number

# %% [markdown]
# Check the number is Prime Number

# %%
def prime_number(num):
    if num <= 1:
        print(num, "is not a prime number")
    else:
        for i in range(2,num):
            if num % i == 0:
                print(num, "is not a prime number")
                break
        else:
            print(num,'is a prime number')
num = int(input("Enter the number: "))
prime_number(num)
# Out:
# 5 is a prime number

# %% [markdown]
# Find the largest of three numbers

# %%
num1 = float(input("Enter the numer 1: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))
if num1 > num2 and num1 > num3:
    print(num1, "is a gratest number")
elif num2 > num1 and num2 > num3:
    print(num2, "is a greatest number")
else:
    print(num3, "is a greatest number")
# Out:
# 5.0 is a greatest number

# %%
num = [100000,609,10]
largest_number = num[0]
for i in range(len(num)):
    if num[i] > largest_number:
        largest_number = num[i]
print("largest number is :",largest_number)
# Out:
# largest number is : 100000

# %% [markdown]
# Check whether a person is eligible to vote based on age.

# %%
age = float(input('Enter your age; '))
if age < 0:
    print("Enter a valid age")
elif age >= 18:
    print("You are adult and you can vote")
else:
    print("You are a Child")
# Out:
# You are a Child

# %% [markdown]
# Calculate the sum of numbers from 1 to N

# %%
total = 0
def calculate_sum(num):
    global total
    for i in range(1,num+1):
        total = total+i
    return total
num = int(input('Enter the number: '))
print(calculate_sum(num))
# Out:
# 15

# %%
num = int(input('Enter the number; '))
total = sum(range(1, (num)+1))
print(total)
# Out:
# 15

# %% [markdown]
# Calculate the factorial of a number

# %%
def calculate_fictorial(num):
    fic = 1
    if num <= 1:
        return 1
    else:
        for i in range(1, num+1):
            fic = fic*i
        return fic
num = int(input("Enter the number"))
calculate_fictorial(num)
# Out:
# 120

# %% [markdown]
# Reverse a number

# %%
num = input("Enter the number: ")
reverse_num = num[::-1]
print(reverse_num)
# Out:
# 5

# %%
reverse = 0
num = int(input("Enter the numbrer; "))
while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num//10
    
print(reverse)
# Out:
# 5

# %% [markdown]
# Count the digits in a number

# %%
num = (input("Enter the numbrer; "))
count = 0
for i in num:
    count +=1
print(count)
# Out:
# 2

# %%
num = (input("Enter the numbrer; "))
print(len(num))
# Out:
# 4

# %% [markdown]
# Check whether a number is a palindrome

# %%
def check_palindrom(num):
    if num == num[::-1]:
        return (num, "is a Palindrom")
    else:
        return (num, "Not not Palindrom")
num = (input("Enter the numbrer; "))
check_palindrom(num)
# Out:
# ('level', 'is a Palindrom')

# %% [markdown]
# Generate the Fibonacci sequence

# %%
def fibnocci(num):
    a = 0
    b = 1
    for i in range(num):
        a,b = b, a+b
    return b

fibnocci(7)
# Out:
# 21

# %%
def fibnocci(num):
    a = 0
    b = 1
    for i in range(num):
        print(a, end = " ")
        a,b = b, a+b
    return b


fibnocci(7)
# Out:
# 0 1 1 2 3 5 8
# 21
